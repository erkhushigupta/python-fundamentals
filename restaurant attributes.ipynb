# %%
#9-1. Restaurant: Make a class called Restaurant. The __init__() method for
#Restaurant should store two attributes: a restaurant_name and a cuisine_type.
#Make a method called describe_restaurant() that prints these two pieces of
#information, and a method called open_restaurant() that prints a message indicating that the restaurant is open.
#Make an instance called restaurant from your class. Print the two attributes
#individually, and then call both methods.
#9-2. Three Restaurants: Start with your class from Exercise 9-1. Create three
#different instances from the class, and call describe_restaurant() for each instance.
#9-3. Users: Make a class called User. Create two attributes called first_name
#and last_name, and then create several other attributes that are typically stored in a user profile. 
#Make a method called describe_user() that prints a summary
#of the user’s information. Make another method called greet_user() that prints a personalized greeting to the user.
#Create several instances representing different users, and call both methods for each user.

#answers for 9.1,9.2 and 9.3 pg 166 
#code

#9-1

class Restaurant:
#defining the Restaurant class with an __init__() method that takes 2 parameters,initializing them (corresponding attributes)
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
#printing the described statements
    def describe_restaurant(self):
        print(f"Restaurant Name: {self.restaurant_name}")
        print(f"Cuisine Type: {self.cuisine_type}")

    def open_restaurant(self):
        print(f"The restaurant {self.restaurant_name} is now open.")


# I Created an instance of the Restaurant class
restaurant = Restaurant("Italian Foods", "Italian")

# Now Printing the attributes individually
print("Restaurant Name:", restaurant.restaurant_name)
print("Cuisine Type:", restaurant.cuisine_type)

# Now finally Calling both methods
restaurant.describe_restaurant()
restaurant.open_restaurant()
class Restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type

    def describe_restaurant(self):
        print(f"Restaurant Name: {self.restaurant_name}")
        print(f"Cuisine Type: {self.cuisine_type}")

    def open_restaurant(self):
        print(f"{self.restaurant_name} is now open!")


 

# Q 9-2
#3 instances of the Restaurant class are created and the describe_restaurant method is called for each instance which tells the speciality
restaurant1 = Restaurant("Pasta Palace", "Italian")
restaurant2 = Restaurant("Sushi Supreme", "Japanese")
restaurant3 = Restaurant("Spice Delight", "Indian")

restaurant1.describe_restaurant()
restaurant2.describe_restaurant()
restaurant3.describe_restaurant()
print()


# Q 9-3
#the User class is defined with attributes such as first name, last name, age, and place.I included describe_user and greet_user methods.
class User:
    def __init__(self, first_name, last_name, age, location):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.location = location

    def describe_user(self):
        print(f"First Name: {self.first_name}")
        print(f"Last Name: {self.last_name}")
        print(f"Age: {self.age}")
        print(f"Location: {self.location}")

    def greet_user(self):
        print(f"Hello, {self.first_name} {self.last_name}!")


user1 = User("John", "W", 25, "LONDON")
user2 = User("Jai", "S", 30, "DELHI")
user3 = User("Ajay", "Kumar", 40, "JAIPUR")
#below will greet each user personally
user1.describe_user()
user1.greet_user()
print()

user2.describe_user()
user2.greet_user()
print()

user3.describe_user()
user3.greet_user()
# Out:
# Restaurant Name: Italian Foods
# Cuisine Type: Italian
# Restaurant Name: Italian Foods
# Cuisine Type: Italian
# The restaurant Italian Foods is now open.
# Restaurant Name: Pasta Palace
# Cuisine Type: Italian
# Restaurant Name: Sushi Supreme
# Cuisine Type: Japanese
# Restaurant Name: Spice Delight
# Cuisine Type: Indian
#
# First Name: John
# Last Name: W
# Age: 25
# Location: LONDON
# Hello, John W!
#
# First Name: Jai
# Last Name: S
# Age: 30
# Location: DELHI
# Hello, Jai S!
#
# First Name: Ajay
# Last Name: Kumar
# Age: 40
# Location: JAIPUR
# Hello, Ajay Kumar!
